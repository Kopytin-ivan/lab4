# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd().parent
DATA_RAW = PROJECT_ROOT / "data" / "raw"
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
FIGURES_DIR = PROJECT_ROOT / "reports" / "figures"

print("Корень проекта:", PROJECT_ROOT)
print("Папка с исходными данными:", DATA_RAW)
print("Папка существует:", DATA_RAW.exists())
# Out:
# Корень проекта: c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project
# Папка с исходными данными: c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project\data\raw
# Папка существует: True

# %%
all_files = list(DATA_RAW.rglob("*"))

print("Всего файлов и папок внутри data/raw:", len(all_files))

audio_files = list(DATA_RAW.rglob("*.au"))
excel_files = list(DATA_RAW.rglob("*.xlsx"))

print("Количество аудиофайлов .au:", len(audio_files))
print("Количество Excel-файлов .xlsx:", len(excel_files))

print("\nПримеры аудиофайлов:")
for file in audio_files[:5]:
    print(file)

print("\nExcel-файлы:")
for file in excel_files:
    print(file)
# Out:
# Всего файлов и папок внутри data/raw: 9067
# Количество аудиофайлов .au: 7448
# Количество Excel-файлов .xlsx: 1
#
# Примеры аудиофайлов:
# c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project\data\raw\Milling Surface Roughness Acoustic Sensor Dataset\feed-10mm\speed-250rpm\doc-0.25mm\10-250-0.25-1\1_data\e00\d00\e0000005.au
# c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project\data\raw\Milling Surface Roughness Acoustic Sensor Dataset\feed-10mm\speed-250rpm\doc-0.25mm\10-250-0.25-1\1_data\e00\d00\e000003d.au
# c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project\data\raw\Milling Surface Roughness Acoustic Sensor Dataset\feed-10mm\speed-250rpm\doc-0.25mm\10-250-0.25-1\1_data\e00\d00\e0000176.au
# c:\Users\ivan.kopytin\Desktop\уник\surface_roughness_project\data\raw\Milling Surface Roughness Acoustic Sensor Dataset\feed-10mm\speed-250rpm\doc-0.25mm\10-250-0.25-1\1_data\e00\d00\e000025b.au
# ...
